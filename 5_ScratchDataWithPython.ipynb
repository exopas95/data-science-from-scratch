# %% [markdown]
# # 파이썬으로 데이터 수집하기

# %% [markdown]
# ## 1. stdin과 stdout

# %%
import sys, re

regex = sys.argv[1]

for line in sys.stdin:
  if re.search(regex, line):
    sys.stdout.write(line)

regex
# Out:
# '-f'
